# %%
# How to combine -> type-1 + type-0

# I can normalize the whole basis (steerable) field to be type-0 (commutes w.r.t. rotations)
# But we don't want to get rid of the type-1 entirely because they capture information about the orientation of the input.
# How to combine this information, it seems it should be relevant to single layer. 
# Can we do something like local attention with angles, cosine similarity might be a option 


# Attention might be a better option. 
# How could we do it for convolution?
