# %%
from escnn import gspaces, nn
channels = 4
r2_act = gspaces.rot2dOnR2(N=-1, maximum_frequency=3)

irreps = 
nn.FieldType(r2_act, irreps[:]) + nn.FieldType(r2_act, irreps)
# Out:
# [SO(2)_on_R2[(None, -1)]: {irrep_1 (x4), irrep_2 (x4), irrep_3 (x4), irrep_1 (x4), irrep_2 (x4), irrep_3 (x4)}(48)]

# %%
irddr.size
# Out:
# 2
